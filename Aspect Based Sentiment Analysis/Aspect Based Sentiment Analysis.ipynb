# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

sns.set()
# %matplotlib inline

# %%
import spacy
from langdetect import detect
from textblob import TextBlob

spacy_eng = spacy.load('en_core_web_sm')

# %%
DATAFILE = 'London_hotel_reviews.csv'
data = pd.read_csv(DATAFILE,encoding='latin-1')

# %%
data.head()
# Out:
#             Property Name  Review Rating  \
# 0  Apex London Wall Hotel              5
# 1  Corinthia Hotel London              5
# 2               The Savoy              5
# 3            Rhodes Hotel              4
# 4               The Savoy              5
#
#                                    Review Title  \
# 0                         Ottima qualità prezzo
# 1            By far, my best hotel in the world
# 2  First visit to the American Bar at the Savoy
# 3                                     Nice stay
# 4                                    Perfection
#
#                                          Review Text  \
# 0  Siamo stati a Londra per un week end ed abbiam...
# 1  I had a pleasure of staying in this hotel for ...
# 2  A very lovely first visit to this iconic hotel...
# 3  3 of us stayed at the Rhodes Hotel for 4 night...
# 4  Form the moment we arrived until we left we ex...
#
#    Location Of The Reviewer Date Of Review
# 0  Casale Monferrato, Italy     10/20/2012
# 1         Savannah, Georgia      3/23/2016
# 2                    London      7/30/2013
# 3              Maui, Hawaii       6/2/2012
# 4    London, United Kingdom     11/24/2017

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27330 entries, 0 to 27329
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Property Name             27330 non-null  object
#  1   Review Rating             27330 non-null  int64
#  2   Review Title              27330 non-null  object
#  3   Review Text               27330 non-null  object
#  4   Location Of The Reviewer  23377 non-null  object
#  5   Date Of Review            27329 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# Number of reviews per hotel

# %%
data['Property Name'].value_counts()
# Out:
# The Savoy                                                         5417
# Mondrian London at Sea Containers                                 4330
# The Rembrandt                                                     3028
# Corinthia Hotel London                                            2820
# Apex London Wall Hotel                                            2205
# The Dorchester                                                    1720
# Rhodes Hotel                                                      1554
# Hotel Xenia, Autograph Collection                                 1524
# Ridgemount Hotel                                                  1365
# Mandarin Oriental Hyde Park, London                               1215
# Bulgari Hotel, London                                              473
# The Wellesley Knightsbridge, a Luxury Collection Hotel, London     354
# The Lanesborough                                                   324
# London Guest House                                                 263
# Newham Hotel                                                       247
# A To Z Hotel                                                       199
# 45 Park Lane - Dorchester Collection                               194
# Hartley Hotel                                                       44
# Marble Arch Hotel                                                   36
# City View Hotel                                                     18
# Name: Property Name, dtype: int64

# %% [markdown]
# <h3> Filter Non English Reviews <h3>

# %%
def filter_non_english(sentence):
    return detect(sentence) == 'en'

non_english_indices = [index for index in tqdm(range(len(data)))
                       if filter_non_english(data.iloc[index]['Review Text']) == False
                      ]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=27330.0), HTML(value='')))

# %%
len(non_english_indices)
# Out:
# 3758

# %%
non_english_df = data.iloc[non_english_indices]
non_english_df
# Out:
#                              Property Name  Review Rating  \
# 0                   Apex London Wall Hotel              5
# 9                             Rhodes Hotel              5
# 23                            A To Z Hotel              5
# 27                        Ridgemount Hotel              5
# 38                  Apex London Wall Hotel              5
# ...                                    ...            ...
# 27317  Mandarin Oriental Hyde Park, London              4
# 27322                            The Savoy              5
# 27323               Corinthia Hotel London              4
# 27326                         A To Z Hotel              3
# 27328                       The Dorchester              4
#
#                                             Review Title  \
# 0                                  Ottima qualità prezzo
# 9                                         Ottima scelta!
# 23                        Excellent rapport qualité prix
# 27                                             Excellent
# 38     Freundliches & zukommendes Personal sowie sehr...
# ...                                                  ...
# 27317                          tolles Gebäude von aussen
# 27322                                Traumhafter Service
# 27323  Il mio primo afternoon tea........ al Corinthi...
# 27326                                       Mala Estadia
# 27328                       Trevliga rum, men högljud AC
#
#                                              Review Text  \
# 0      Siamo stati a Londra per un week end ed abbiam...
# 9      Ottimo rapporto qualità - prezzo, ottima la po...
# 23     A 15 mn à pied, 5 en bus (passage fréquent) de...
# 27     Nous avons pris l'habitude de descendre dans c...
# 38     Wir waren im Rahmen einer Städtereise für 3 Üb...
# ...                                                  ...
# 27317  schönes Haus von aussen und im Lobby/bar Berei...
# 27322  Wir haben gerade 4 Tage im The Savoy in London...
# 27323  Io e mio marito, abbiamo passato le vacanze di...
# 27326  En cuarto que nos tocó no había toallas y habí...
# 27328  Väldigt vackra rum, tyvärr med en mycket höglj...
#
#        Location Of The Reviewer Date Of Review
# 0      Casale Monferrato, Italy     10/20/2012
# 9                      Cagliari       2/7/2011
# 23                Paris, France       1/5/2016
# 27          Zurich, Switzerland     10/30/2011
# 38          Roedermark, Germany      9/15/2012
# ...                         ...            ...
# 27317       Zurich, Switzerland      5/29/2012
# 27322                   Hamburg     11/18/2014
# 27323                       NaN      1/25/2015
# 27326       Mexico City, Mexico      9/29/2015
# 27328        Gothenburg, Sweden       5/6/2014
#
# [3758 rows x 6 columns]

# %%
data = data.drop(non_english_indices,axis = 0)
data = data.drop(['Location Of The Reviewer','Date Of Review'],axis=1)
data.head()
# Out:
#             Property Name  Review Rating  \
# 1  Corinthia Hotel London              5
# 2               The Savoy              5
# 3            Rhodes Hotel              4
# 4               The Savoy              5
# 5  Corinthia Hotel London              1
#
#                                    Review Title  \
# 1            By far, my best hotel in the world
# 2  First visit to the American Bar at the Savoy
# 3                                     Nice stay
# 4                                    Perfection
# 5                         Staff stole from me!!
#
#                                          Review Text
# 1  I had a pleasure of staying in this hotel for ...
# 2  A very lovely first visit to this iconic hotel...
# 3  3 of us stayed at the Rhodes Hotel for 4 night...
# 4  Form the moment we arrived until we left we ex...
# 5  Well I am no strange to London's 5star hotels ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23572 entries, 1 to 27329
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Property Name  23572 non-null  object
#  1   Review Rating  23572 non-null  int64
#  2   Review Title   23572 non-null  object
#  3   Review Text    23572 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 920.8+ KB

# %%
# case text as lowercase, remove punctuation, remove extra whitespace in string and on both sides of string

data['review_cleaned'] = data['Review Text'].str.lower().str.replace("'", '').str.replace('[^\w\s]', ' ').str.replace(" \d+", " ").str.replace(' +', ' ').str.strip()

# %%
data
# Out:
#                              Property Name  Review Rating  \
# 1                   Corinthia Hotel London              5
# 2                                The Savoy              5
# 3                             Rhodes Hotel              4
# 4                                The Savoy              5
# 5                   Corinthia Hotel London              1
# ...                                    ...            ...
# 27321    Mondrian London at Sea Containers              5
# 27324  Mandarin Oriental Hyde Park, London              4
# 27325               Corinthia Hotel London              5
# 27327                        The Rembrandt              4
# 27329                            The Savoy              5
#
#                                        Review Title  \
# 1                By far, my best hotel in the world
# 2      First visit to the American Bar at the Savoy
# 3                                         Nice stay
# 4                                        Perfection
# 5                             Staff stole from me!!
# ...                                             ...
# 27321                               Birthday Brunch
# 27324                      We love it every time!!!
# 27325        The Best 5 star Luxury Hotel in London
# 27327       Excellent hotel in outstanding location
# 27329                               Great as always
#
#                                              Review Text  \
# 1      I had a pleasure of staying in this hotel for ...
# 2      A very lovely first visit to this iconic hotel...
# 3      3 of us stayed at the Rhodes Hotel for 4 night...
# 4      Form the moment we arrived until we left we ex...
# 5      Well I am no strange to London's 5star hotels ...
# ...                                                  ...
# 27321  Recently came here for a friends birthday. We ...
# 27324  Greatly located with lovely views of the park ...
# 27325  I come to London often but since I stayed in t...
# 27327  This is a quality quiet hotel located in an ex...
# 27329  I have been staying in London hotels for 10 ye...
#
#                                           review_cleaned
# 1      i had a pleasure of staying in this hotel for ...
# 2      a very lovely first visit to this iconic hotel...
# 3      3 of us stayed at the rhodes hotel for nights ...
# 4      form the moment we arrived until we left we ex...
# 5      well i am no strange to londons star hotels an...
# ...                                                  ...
# 27321  recently came here for a friends birthday we d...
# 27324  greatly located with lovely views of the park ...
# 27325  i come to london often but since i stayed in t...
# 27327  this is a quality quiet hotel located in an ex...
# 27329  i have been staying in london hotels for years...
#
# [23572 rows x 5 columns]

# %%
for sentence in data['review_cleaned'].head(3).tolist():
    doc = spacy_eng(sentence)
    
    descriptive_terms = []
    
    for token in doc:
        if token.pos_ == 'ADJ':
            descriptive_terms.append(token)
    print('Sentence: \n============================================')
    print(sentence)
    print('Descriptive Terms: \n====================================')
    print(descriptive_terms)
    print('-'*50)
# Out:
# Sentence
# ============================================
# i had a pleasure of staying in this hotel for nights recently this hotel was perfect in every way communication with the hotel before staying was prompt and very efficient checking in was a breeze you go through the spectacular lobby with modern glass chandeliers and take the elevator to your room my room they gave me an upgrade to junior suite was spectacular we had a walk in closet of the size where you could have put a small bed in there it served us nicely for the seven day stay the decor was very refined and oh the bathroom carrera marble floor was heated throughout rain shower was to die for location as it turned out was as good as it can be we were minutes walk to trafalgar square but it was very quiet right outside was embankment tube stop we would walk to theater area and to numerous restaurants and many major sites such as london eye or westminster abbey were within walking distance we had buffet breakfast or room service every morning it was pricy but my rate included it couple of nights we had glass of wine sitting in front of fire place in the lobby i used the spa which is included in the room rate almost every night after a windchill day of sightseeing the steam sauna and jacuzzi would soften my weary muscles i have stayed in many star hotels around the world but this hotel tops it i would return here in a heartbeat next time i am in london
# Descriptive Term
# ====================================
# [perfect, prompt, efficient, spectacular, modern, junior, spectacular, small, refined, good, square, quiet, numerous, many, major, such, weary, many, next]
# --------------------------------------------------
# Sentence
# ============================================
# a very lovely first visit to this iconic hotel bar wonderful service without being intrusive at all very delicious cocktails and just generally all round a very indulgent experience well worth visiting only for that once in a lifetime experience though do make sure you are feeling flush it doesnt come cheap
# Descriptive Term
# ====================================
# [lovely, first, iconic, wonderful, intrusive, delicious, indulgent, worth, sure, flush, cheap]
# --------------------------------------------------
# Sentence
# ============================================
# 3 of us stayed at the rhodes hotel for nights its a great location for taking the paddington express from heathrow we like the location clost to the partk and in walking distance of most locations the room and bath were small compared to american hotels but very clean we enjoyed the free wifi the owners and the staff were very friendly and helpful with taxis and resturant recomendations we would stay there again
# Descriptive Term
# ====================================
# [great, most, small, american, clean, free, friendly, helpful, resturant]
# --------------------------------------------------

# %% [markdown]
# Extracting intensifiers of the adjectives

# %%
for sentence in data['review_cleaned'].head(3).tolist():
    doc = spacy_eng(sentence)
    
    descriptive_terms = []
    
    for token in doc:
        if token.pos_ == 'ADJ':
            intensifier = ''
            for child in token.children:
                if child.pos_ != 'ADV':
                    continue
                intensifier += child.text + ' '
            descriptive_term = intensifier + token.text
            descriptive_terms.append(descriptive_term)
    print('Sentence: \n============================================')
    print(sentence)
    print('Descriptive Terms: \n====================================')
    print(descriptive_terms)
    print('-'*50)
# Out:
# Sentence:
# ============================================
# i had a pleasure of staying in this hotel for nights recently this hotel was perfect in every way communication with the hotel before staying was prompt and very efficient checking in was a breeze you go through the spectacular lobby with modern glass chandeliers and take the elevator to your room my room they gave me an upgrade to junior suite was spectacular we had a walk in closet of the size where you could have put a small bed in there it served us nicely for the seven day stay the decor was very refined and oh the bathroom carrera marble floor was heated throughout rain shower was to die for location as it turned out was as good as it can be we were minutes walk to trafalgar square but it was very quiet right outside was embankment tube stop we would walk to theater area and to numerous restaurants and many major sites such as london eye or westminster abbey were within walking distance we had buffet breakfast or room service every morning it was pricy but my rate included it couple of nights we had glass of wine sitting in front of fire place in the lobby i used the spa which is included in the room rate almost every night after a windchill day of sightseeing the steam sauna and jacuzzi would soften my weary muscles i have stayed in many star hotels around the world but this hotel tops it i would return here in a heartbeat next time i am in london
# Descriptive Terms:
# ====================================
# ['perfect', 'prompt', 'very efficient', 'spectacular', 'modern', 'junior', 'spectacular', 'small', 'very refined', 'as good', 'square', 'very quiet', 'numerous', 'many', 'major', 'such', 'weary', 'many', 'next']
# --------------------------------------------------
# Sentence:
# ============================================
# a very lovely first visit to this iconic hotel bar wonderful service without being intrusive at all very delicious cocktails and just generally all round a very indulgent experience well worth visiting only for that once in a lifetime experience though do make sure you are feeling flush it doesnt come cheap
# Descriptive Terms:
# ====================================
# ['very lovely', 'first', 'iconic', 'wonderful', 'intrusive', 'very delicious', 'very indulgent', 'well worth', 'sure', 'flush', 'cheap']
# --------------------------------------------------
# Sentence:
# ============================================
# 3 of us stayed at the rhodes hotel for nights its a great location for taking the paddington express from heathrow we like the location clost to the partk and in walking distance of most locations the room and bath were small compared to american hotels but very clean we enjoyed the free wifi the owners and the staff were very friendly and helpful with taxis and resturant recomendations we would stay there again
# Descriptive Terms:
# ====================================
# ['great', 'most', 'small', 'american', 'very clean', 'free', 'very friendly', 'helpful', 'resturant']
# --------------------------------------------------

# %%
def extract_aspects(sentence):
    doc = spacy_eng(sentence)
    descriptive_term = ''
    target = ''
    temp_aspects = []
    
    for token in doc:
        if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
            target = token.text
            
        if token.pos_ == 'ADJ':
                intensifier = ''
                
                for child in token.children:
                    if child.pos_ != 'ADV':
                        continue
                    intensifier += child.text + ' '
                descriptive_term = intensifier + token.text
                temp_aspects.append({'aspect': target ,
                               'description': descriptive_term})
                
    return temp_aspects

# %%
extract_aspects(data['Review Text'].iloc[0])
# Out:
# [{'aspect': 'hotel', 'description': 'perfect'},
#  {'aspect': 'Communication', 'description': 'prompt'},
#  {'aspect': 'Communication', 'description': 'very efficient'},
#  {'aspect': 'Communication', 'description': 'spectacular'},
#  {'aspect': 'Communication', 'description': 'modern'},
#  {'aspect': 'Communication', 'description': 'junior'},
#  {'aspect': 'Communication', 'description': 'spectacular'},
#  {'aspect': 'Communication', 'description': 'small'},
#  {'aspect': 'decor', 'description': 'very refined'},
#  {'aspect': 'shower', 'description': 'as good'},
#  {'aspect': 'shower', 'description': 'very quiet'},
#  {'aspect': 'shower', 'description': 'numerous'},
#  {'aspect': 'shower', 'description': 'many'},
#  {'aspect': 'shower', 'description': 'major'},
#  {'aspect': 'sites', 'description': 'such'},
#  {'aspect': 'sauna', 'description': 'weary'},
#  {'aspect': 'sauna', 'description': 'many'},
#  {'aspect': 'hotel', 'description': 'next'}]

# %%
aspects = {'aspect':list(),'description':list()}

for i in tqdm(range(len(data))):
    
    for curr_sent_aspect in extract_aspects(data['Review Text'].iloc[i]):
        curr_aspect = curr_sent_aspect['aspect']
        if aspect == '':
            continue
        
        aspects['aspect'].append(curr_aspect)
        aspects['description'].append(curr_sent_aspect['description'])
        
aspects = pd.DataFrame(aspects)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=23572.0), HTML(value='')))

# %%
aspects
# Out:
#                aspect     description
# 0               hotel         perfect
# 1       Communication          prompt
# 2       Communication  very efficient
# 3       Communication     spectacular
# 4       Communication          modern
# ...               ...             ...
# 318912          staff       excellent
# 318913          savoy       favourite
# 318914          savoy             new
# 318915          savoy         welcome
# 318916      breakfast       favourite
#
# [318917 rows x 2 columns]

# %%
polarity = []
subjectivity = []
for i in tqdm(range(len(aspects))):
    sentiment = TextBlob(aspects['description'].iloc[i]).sentiment
    polarity.append(sentiment.polarity)
    subjectivity.append(sentiment.subjectivity)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=318917.0), HTML(value='')))

# %%
aspects['polarity'] = polarity
aspects['subjectivity'] = subjectivity

# %%
aspects
# Out:
#                aspect     description  polarity  subjectivity
# 0               hotel         perfect  1.000000      1.000000
# 1       Communication          prompt  0.000000      0.000000
# 2       Communication  very efficient  0.200000      0.300000
# 3       Communication     spectacular  0.600000      0.900000
# 4       Communication          modern  0.200000      0.300000
# ...               ...             ...       ...           ...
# 318912          staff       excellent  1.000000      1.000000
# 318913          savoy       favourite  0.000000      0.000000
# 318914          savoy             new  0.136364      0.454545
# 318915          savoy         welcome  0.800000      0.900000
# 318916      breakfast       favourite  0.000000      0.000000
#
# [318917 rows x 4 columns]

# %%
counts = aspects['aspect'].value_counts()

# %%
spurious_aspects = [asp for asp,val in counts.items() if val < 5]

# %%
spurious_aspects[60:100]
# Out:
# ['rep',
#  'Steps',
#  'Foyer',
#  'Plumbing',
#  'Door',
#  'hardware',
#  'goal',
#  'outpost',
#  'princess',
#  'grandchildren',
#  'cosies',
#  'proof',
#  'assistant',
#  'themes',
#  'tape',
#  'yogamat',
#  'privacy',
#  'enthusiast',
#  'reference',
#  'myriad',
#  'labeling',
#  'bills',
#  'ballrooms',
#  'Gold',
#  'oils',
#  'Jaime',
#  'habit',
#  'pain',
#  'irritations',
#  'tasting',
#  'granddaughters',
#  '.It',
#  '.service',
#  'wings',
#  'tunes',
#  'conceige',
#  'elite',
#  'Trains',
#  'rooftop',
#  'grail']

# %%
def get_sentiment(polarity):
    if polarity > 0.1:
        return 1
    elif polarity >-0.1 and polarity < 0.1:
        return 0
    elif polarity < -0.1:
        return -1

# %%
aspects['sentiment'] = aspects['polarity'].apply(get_sentiment)

# %%
aspects
# Out:
#                aspect     description  polarity  subjectivity  sentiment
# 0               hotel         perfect  1.000000      1.000000        1.0
# 1       Communication          prompt  0.000000      0.000000        0.0
# 2       Communication  very efficient  0.200000      0.300000        1.0
# 3       Communication     spectacular  0.600000      0.900000        1.0
# 4       Communication          modern  0.200000      0.300000        1.0
# ...               ...             ...       ...           ...        ...
# 318912          staff       excellent  1.000000      1.000000        1.0
# 318913          savoy       favourite  0.000000      0.000000        0.0
# 318914          savoy             new  0.136364      0.454545        1.0
# 318915          savoy         welcome  0.800000      0.900000        1.0
# 318916      breakfast       favourite  0.000000      0.000000        0.0
#
# [318917 rows x 5 columns]

# %%
aspects['sentiment'].value_counts()
# Out:
#  1.0    181969
#  0.0     95529
# -1.0     33678
# Name: sentiment, dtype: int64
